# %%
import myutils
from mypytable import MyPyTable
import mypytable
import plot_utils
import importlib
import os

importlib.reload(myutils)
importlib.reload(mypytable)
importlib.reload(plot_utils)
# Out:
# <module 'plot_utils' from '/home/cpsc322-Final-Project/plot_utils.py'>

# %%
# Load data into a mypytable
players_table = MyPyTable()
players_table.load_from_file("cleaned-data.txt")
# get salaries column
salaries = players_table.get_column("avg_salary")

# %%
#Points
col = players_table.get_column("career_PTS")
plot_utils.plot_scatter(col, salaries)

# %%
# PER
col = players_table.get_column("career_PER")
plot_utils.plot_scatter(col, salaries)

# %%
# draft year
col = players_table.get_column("draft_year")
plot_utils.plot_scatter(col, salaries)

# %%
# games played 
col = players_table.get_column("career_G")
plot_utils.plot_scatter(col, salaries)

# %%
# effective field goal %
col = players_table.get_column("career_eFG%")
plot_utils.plot_scatter(col, salaries)

# %%
# win shares
col = players_table.get_column("career_WS")
plot_utils.plot_scatter(col, salaries)
